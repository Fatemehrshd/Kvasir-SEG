# %% [markdown]
# # U-net Model with fig-size 128*128 and the traning plots

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import os
import cv2

from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Resizing

# %% [markdown]
# read images and resize them: size = (128, 128, 3)

# %%
def read_images_from_folder_and_resizing(img_folder_path, mask_folder_path):
    images = []
    masks  = []
    img_paths  = []
    mask_paths = []
    for image_name in sorted(os.listdir(img_folder_path)):
        image_path = os.path.join(img_folder_path, image_name)
        img_paths.append(image_path)

    for mask_name in sorted(os.listdir(mask_folder_path)):
        mask_path = os.path.join(mask_folder_path, mask_name)
        mask_paths.append(mask_path)

    for img_path, mask_path in zip(img_paths, mask_paths):
        img  = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        desired_size = (128, 128)
        img  = cv2.resize(img, desired_size)
        mask = cv2.resize(mask, desired_size)

        images.append(img)
        masks.append(mask)
    return images, masks, img_paths, mask_paths



images_folder_path = 'Kvasir-SEG/images'
masks_folder_path  = 'Kvasir-SEG/masks'

images, masks, img_p, mask_p = read_images_from_folder_and_resizing(images_folder_path, masks_folder_path)
images = np.array(images)
masks  = np.array(masks)

# %% [markdown]
# ### Normalization

# %%
images = images / 255.
masks  = masks / 255.

print("Max pixel value (mask):", np.max(images))
print("Min pixel value (mask):", np.min(masks))
# Out:
# Max pixel value (mask): 1.0
# Min pixel value (mask): 0.0

# %% [markdown]
# ### Display an instance of normalized images and its mask

# %%
plt.figure(figsize=(10, 5))

# Display the first image
plt.subplot(1, 2, 1)
plt.imshow(images[2])
plt.title('Image')

# Display the first mask
plt.subplot(1, 2, 2)
plt.imshow(masks[2], cmap='gray')
plt.title('Mask')

plt.show()

# %% [markdown]
# ### Spliting data into train, validation, and test.

# %%
def split_data(images, masks, split=0.1):
    total_size = len(images)
    test_size  = int(split * total_size)
    valid_size = int(split * total_size)

    X_train, X_valid = train_test_split(images, test_size=valid_size, random_state=42)
    y_train, y_valid = train_test_split(masks, test_size=valid_size, random_state=42)

    X_train, X_test = train_test_split(X_train, test_size=test_size, random_state=42)
    y_train, y_test = train_test_split(y_train, test_size=test_size, random_state=42)
    return (X_train, y_train), (X_valid, y_valid), (X_test, y_test)

# %%
(X_train, y_train), (X_valid, y_valid), (X_test, y_test) = split_data(images, masks)

print(f"train set size: {len(X_train)}\nvalid set size: {len(X_valid)}\ntest set size:  {len(X_test)}")
# Out:
# train set size: 800
# valid set size: 100
# test set size:  100

# %% [markdown]
# ## Construct U-net model

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Concatenate, UpSampling2D, Conv2DTranspose, BatchNormalization, Dropout
from tensorflow.keras.models import Model

def Unet(input_shape):

    inputs = Input(input_shape)

    layer1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    # layer5 = Dropout(0.5)(layer1)
    layer1 = Conv2D(16, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer1)
    pool1  = MaxPooling2D(pool_size=(2, 2))(layer1)

    layer2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool1)
    # layer5 = Dropout(0.5)(layer2)
    layer2 = Conv2D(32, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer2)
    pool2  = MaxPooling2D(pool_size=(2, 2))(layer2)

    layer3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool2)
    # layer5 = Dropout(0.3)(layer3)
    layer3 = Conv2D(64, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer3)
    pool3  = MaxPooling2D(pool_size=(2, 2))(layer3)

    layer4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool3)
    # layer5 = Dropout(0.3)(layer4)
    layer4 = Conv2D(128, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer4)
    pool4  = MaxPooling2D(pool_size=(2, 2))(layer4)

    layer5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool4)
    layer5 = Dropout(0.3)(layer5)
    layer5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(layer5)

    upsam1 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(layer5)
    upsam1 = Concatenate()([upsam1, layer4])
    layer6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam1)

    upsam2 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(layer6)
    upsam2 = Concatenate()([upsam2, layer3])
    layer7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam2)

    upsam3 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(layer7)
    upsam3 = Concatenate()([upsam3, layer2])
    layer8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam3)

    upsam4 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(layer8)
    upsam4 = Concatenate()([upsam4, layer1])
    layer9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam4)

    layer10= Conv2D(1, (1, 1), activation='sigmoid')(layer9)

    model = Model(inputs=inputs, outputs=layer10)

    return model

# %%
model = Unet((128, 128, 3))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃ Param # ┃ Connected to         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │       0 │ -                    │
# │ (InputLayer)        │ 3)                │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │     448 │ input_layer[0][0]    │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │   2,320 │ conv2d[0][0]         │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │       0 │ conv2d_1[0][0]       │
# │ (MaxPooling2D)      │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │   4,640 │ max_pooling2d[0][0]  │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │   9,248 │ conv2d_2[0][0]       │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │       0 │ conv2d_3[0][0]       │
# │ (MaxPooling2D)      │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │  18,496 │ max_pooling2d_1[0][… │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │  36,928 │ conv2d_4[0][0]       │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │       0 │ conv2d_5[0][0]       │
# │ (MaxPooling2D)      │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  73,856 │ max_pooling2d_2[0][… │
# │                     │ 128)              │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │ 147,584 │ conv2d_6[0][0]       │
# │                     │ 128)              │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │       0 │ conv2d_7[0][0]       │
# │ (MaxPooling2D)      │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │ 295,168 │ max_pooling2d_3[0][… │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ dropout (Dropout)   │ (None, 8, 8, 256) │       0 │ conv2d_8[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │ 590,080 │ dropout[0][0]        │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │ 131,200 │ conv2d_9[0][0]       │
# │ (Conv2DTranspose)   │ 128)              │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate         │ (None, 16, 16,    │       0 │ conv2d_transpose[0]… │
# │ (Concatenate)       │ 256)              │         │ conv2d_7[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │ 295,040 │ concatenate[0][0]    │
# │                     │ 128)              │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │  32,832 │ conv2d_10[0][0]      │
# │ (Conv2DTranspose)   │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │       0 │ conv2d_transpose_1[… │
# │ (Concatenate)       │ 128)              │         │ conv2d_5[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  73,792 │ concatenate_1[0][0]  │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │   8,224 │ conv2d_11[0][0]      │
# │ (Conv2DTranspose)   │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │       0 │ conv2d_transpose_2[… │
# │ (Concatenate)       │ 64)               │         │ conv2d_3[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  18,464 │ concatenate_2[0][0]  │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │   2,064 │ conv2d_12[0][0]      │
# │ (Conv2DTranspose)   │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │       0 │ conv2d_transpose_3[… │
# │ (Concatenate)       │ 32)               │         │ conv2d_1[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │   4,624 │ concatenate_3[0][0]  │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │      17 │ conv2d_13[0][0]      │
# │                     │ 1)                │         │                      │
# └─────────────────────┴───────────────────┴─────────┴──────────────────────┘
#  Total params: 1,745,025 (6.66 MB)
#  Trainable params: 1,745,025 (6.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Define functions for metrics Dice and IoU

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_loss(y_true, y_pred, smooth=100):
    return -dice_coef(y_true, y_pred, smooth)


def iou_coef(y_true, y_pred, smooth=100):
    y_true = K.expand_dims(y_true, axis=-1)
    
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    
    return iou

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# ### Compile the model

# %%
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', iou_coef, dice_coef])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', iou_coef, dice_coef])

# %% [markdown]
# ### Fit the model with epochs=25 and batch_size=32

# %%
history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=25, batch_size=32)
# Out:
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5398 - dice_coef: 0.1987 - iou_coef: 0.1117 - loss: 0.8301 - val_accuracy: 0.8302 - val_dice_coef: 0.2171 - val_iou_coef: 0.1228 - val_loss: 0.4167
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8405 - dice_coef: 0.2390 - iou_coef: 0.1363 - loss: 0.3889 - val_accuracy: 0.8302 - val_dice_coef: 0.2549 - val_iou_coef: 0.1472 - val_loss: 0.3648
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8430 - dice_coef: 0.2640 - iou_coef: 0.1526 - loss: 0.3573 - val_accuracy: 0.8302 - val_dice_coef: 0.2856 - val_iou_coef: 0.1679 - val_loss: 0.3450
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8423 - dice_coef: 0.2854 - iou_coef: 0.1671 - loss: 0.3400 - val_accuracy: 0.8315 - val_dice_coef: 0.2992 - val_iou_coef: 0.1774 - val_loss: 0.3400
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8496 - dice_coef: 0.2911 - iou_coef: 0.1710 - loss: 0.3356 - val_accuracy: 0.8343 - val_dice_coef: 0.2981 - val_iou_coef: 0.1766 - val_loss: 0.3370
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8511 - dice_coef: 0.3090 - iou_coef: 0.1833 - loss: 0.3266 - val_accuracy: 0.8470 - val_dice_coef: 0.3094 - val_iou_coef: 0.1846 - val_loss: 0.3326
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8650 - dice_coef: 0.3268 - iou_coef: 0.1962 - loss: 0.3065 - val_accuracy: 0.8531 - val_dice_coef: 0.3334 - val_iou_coef: 0.2018 - val_loss: 0.3245
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8625 - dice_coef: 0.3489 - iou_coef: 0.2118 - loss: 0.3072 - val_accuracy: 0.8589 - val_dice_coef: 0.3472 - val_iou_coef: 0.2118 - val_loss: 0.3174
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8732 - dice_coef: 0.3711 - iou_coef: 0.2285 - loss: 0.2903 - val_accuracy: 0.8436 - val_dice_coef: 0.3751 - val_iou_coef: 0.2330 - val_loss: 0.3350
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8740 - dice_coef: 0.3860 - iou_coef: 0.2397 - loss: 0.2864 - val_accuracy: 0.8437 - val_dice_coef: 0.2675 - val_iou_coef: 0.1563 - val_loss: 0.3660
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8450 - dice_coef: 0.3531 - iou_coef: 0.2174 - loss: 0.3533 - val_accuracy: 0.8652 - val_dice_coef: 0.3950 - val_iou_coef: 0.2485 - val_loss: 0.3057
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8820 - dice_coef: 0.4344 - iou_coef: 0.2786 - loss: 0.2706 - val_accuracy: 0.8764 - val_dice_coef: 0.4510 - val_iou_coef: 0.2939 - val_loss: 0.2864
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8859 - dice_coef: 0.4695 - iou_coef: 0.3078 - loss: 0.2589 - val_accuracy: 0.8711 - val_dice_coef: 0.4768 - val_iou_coef: 0.3159 - val_loss: 0.2812
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8989 - dice_coef: 0.5054 - iou_coef: 0.3393 - loss: 0.2333 - val_accuracy: 0.8811 - val_dice_coef: 0.4470 - val_iou_coef: 0.2899 - val_loss: 0.2845
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8996 - dice_coef: 0.5256 - iou_coef: 0.3580 - loss: 0.2396 - val_accuracy: 0.8820 - val_dice_coef: 0.4380 - val_iou_coef: 0.2828 - val_loss: 0.2751
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9036 - dice_coef: 0.5329 - iou_coef: 0.3651 - loss: 0.2238 - val_accuracy: 0.8813 - val_dice_coef: 0.4499 - val_iou_coef: 0.2924 - val_loss: 0.2851
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9077 - dice_coef: 0.5657 - iou_coef: 0.3957 - loss: 0.2164 - val_accuracy: 0.8931 - val_dice_coef: 0.5481 - val_iou_coef: 0.3796 - val_loss: 0.2450
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9193 - dice_coef: 0.6129 - iou_coef: 0.4433 - loss: 0.1872 - val_accuracy: 0.8960 - val_dice_coef: 0.5585 - val_iou_coef: 0.3887 - val_loss: 0.2364
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9171 - dice_coef: 0.6295 - iou_coef: 0.4606 - loss: 0.1927 - val_accuracy: 0.8916 - val_dice_coef: 0.5615 - val_iou_coef: 0.3923 - val_loss: 0.2495
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9265 - dice_coef: 0.6578 - iou_coef: 0.4914 - loss: 0.1705 - val_accuracy: 0.8814 - val_dice_coef: 0.5462 - val_iou_coef: 0.3784 - val_loss: 0.2641
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9304 - dice_coef: 0.6798 - iou_coef: 0.5158 - loss: 0.1605 - val_accuracy: 0.9004 - val_dice_coef: 0.5744 - val_iou_coef: 0.4071 - val_loss: 0.2458
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9353 - dice_coef: 0.6866 - iou_coef: 0.5257 - loss: 0.1474 - val_accuracy: 0.8966 - val_dice_coef: 0.6252 - val_iou_coef: 0.4564 - val_loss: 0.2611
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9348 - dice_coef: 0.7141 - iou_coef: 0.5564 - loss: 0.1477 - val_accuracy: 0.9053 - val_dice_coef: 0.6374 - val_iou_coef: 0.4697 - val_loss: 0.2399
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9469 - dice_coef: 0.7737 - iou_coef: 0.6321 - loss: 0.1151 - val_accuracy: 0.9018 - val_dice_coef: 0.6018 - val_iou_coef: 0.4330 - val_loss: 0.2526
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9460 - dice_coef: 0.7794 - iou_coef: 0.6396 - loss: 0.1175 - val_accuracy: 0.9085 - val_dice_coef: 0.6418 - val_iou_coef: 0.4751 - val_loss: 0.2476

# %% [markdown]
# ## Results and analysis

# %%
loss, accuracy, iou, dice = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}\nTest Accuracy: {accuracy}\nIoU: {iou}\nDice: {dice}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.8995 - dice_coef: 0.6498 - iou_coef: 0.4818 - loss: 0.2715
# Test Loss: 0.25238126516342163
# Test Accuracy: 0.9005853533744812
# IoU: 0.6536980867385864
# Dice: 0.48646873235702515

# %% [markdown]
# ### Plot training metrics

# %%
def plot_training(hist):

    # Define needed variables
    tr_acc = hist.history['accuracy']
    tr_iou = hist.history['iou_coef']
    tr_dice = hist.history['dice_coef']
    tr_loss = hist.history['loss']

    val_acc = hist.history['val_accuracy']
    val_iou = hist.history['val_iou_coef']
    val_dice = hist.history['val_dice_coef']
    val_loss = hist.history['val_loss']

    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    index_iou = np.argmax(iou_coef)
    iou_highest = val_iou[index_iou]
    index_dice = np.argmax(dice_coef)
    dice_highest = val_dice[index_dice]
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]

    Epochs = [i+1 for i in range(len(tr_acc))]

    acc_label = f'best epoch= {str(index_acc + 1)}'
    iou_label = f'best epoch= {str(index_iou + 1)}'
    dice_label = f'best epoch= {str(index_dice + 1)}'
    loss_label = f'best epoch= {str(index_loss + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 20))
    plt.style.use('fivethirtyeight')

    # Training Accuracy
    plt.subplot(2, 2, 1)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training IoU
    plt.subplot(2, 2, 2)
    plt.plot(Epochs, tr_iou, 'r', label= 'Training IoU')
    plt.plot(Epochs, val_iou, 'g', label= 'Validation IoU')
    plt.scatter(index_iou + 1 , iou_highest, s= 150, c= 'blue', label= iou_label)
    plt.title('Training and Validation IoU Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('IoU')
    plt.legend()

    # Training Dice
    plt.subplot(2, 2, 3)
    plt.plot(Epochs, tr_dice, 'r', label= 'Training Dice')
    plt.plot(Epochs, val_dice, 'g', label= 'Validation Dice')
    plt.scatter(index_dice + 1 , dice_highest, s= 150, c= 'blue', label= dice_label)
    plt.title('Training and Validation Dice Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('Dice')
    plt.legend()

    # Training Loss
    plt.subplot(2, 2, 4)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %% [markdown]
# ### Show the predictions

# %%
predictions = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 337ms/step

# %%
num_images = 10
plt.figure(figsize=(20, 10))
for i in range(10):
    plt.subplot(3, num_images, i + 1)
    plt.imshow(X_test[i])
    plt.title('Test Image')
    plt.axis('off')
    
    plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(y_test[i], cmap='gray')
    plt.title('Ground Truth Mask')
    plt.axis('off')
    
    plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(predictions[i], cmap='gray')
    plt.title('Predicted Mask')
    plt.axis('off')

plt.show()
