# %% [markdown]
# # U-net Model with fig-size 64*64 and the traning plots

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import os
import cv2

from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Resizing

# %% [markdown]
# read images and resize them: size = (64, 64, 3)

# %%
def read_images_from_folder_and_resizing(img_folder_path, mask_folder_path):
    images = []
    masks  = []
    img_paths  = []
    mask_paths = []
    for image_name in sorted(os.listdir(img_folder_path)):
        image_path = os.path.join(img_folder_path, image_name)
        img_paths.append(image_path)

    for mask_name in sorted(os.listdir(mask_folder_path)):
        mask_path = os.path.join(mask_folder_path, mask_name)
        mask_paths.append(mask_path)

    for img_path, mask_path in zip(img_paths, mask_paths):
        img  = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        desired_size = (64, 64)
        img  = cv2.resize(img, desired_size)
        mask = cv2.resize(mask, desired_size)

        images.append(img)
        masks.append(mask)
    return images, masks, img_paths, mask_paths



images_folder_path = 'Kvasir-SEG/images'
masks_folder_path  = 'Kvasir-SEG/masks'

images, masks, img_p, mask_p = read_images_from_folder_and_resizing(images_folder_path, masks_folder_path)
images = np.array(images)
masks  = np.array(masks)

# %% [markdown]
# ### Normalizing

# %%
images = images / 255.
masks  = masks / 255.

print("Max pixel value (mask):", np.max(images))
print("Min pixel value (mask):", np.min(masks))
# Out:
# Max pixel value (mask): 1.0
# Min pixel value (mask): 0.0

# %% [markdown]
# ### Display an instance of normalized images and its mask

# %%
plt.figure(figsize=(10, 5))

# Display the first image
plt.subplot(1, 2, 1)
plt.imshow(images[2])
plt.title('Image')

# Display the first mask
plt.subplot(1, 2, 2)
plt.imshow(masks[2], cmap='gray')
plt.title('Mask')

plt.show()

# %% [markdown]
# ### Spliting data into train, validation, and test.

# %%
def split_data(images, masks, split=0.1):
    total_size = len(images)
    test_size  = int(split * total_size)
    valid_size = int(split * total_size)

    X_train, X_valid = train_test_split(images, test_size=valid_size, random_state=42)
    y_train, y_valid = train_test_split(masks, test_size=valid_size, random_state=42)

    X_train, X_test = train_test_split(X_train, test_size=test_size, random_state=42)
    y_train, y_test = train_test_split(y_train, test_size=test_size, random_state=42)
    return (X_train, y_train), (X_valid, y_valid), (X_test, y_test)

# %%
(X_train, y_train), (X_valid, y_valid), (X_test, y_test) = split_data(images, masks)

print(f"train set size: {len(X_train)}\nvalid set size: {len(X_valid)}\ntest set size:  {len(X_test)}")
# Out:
# train set size: 800
# valid set size: 100
# test set size:  100

# %% [markdown]
# ## Construct U-net model

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Concatenate, UpSampling2D, Conv2DTranspose, BatchNormalization, Dropout
from tensorflow.keras.models import Model

def Unet(input_shape):

    inputs = Input(input_shape)

    layer1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    layer1 = Conv2D(16, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer1)
    pool1  = MaxPooling2D(pool_size=(2, 2))(layer1)

    layer2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool1)
    layer2 = Conv2D(32, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer2)
    pool2  = MaxPooling2D(pool_size=(2, 2))(layer2)

    layer3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool2)
    layer3 = Conv2D(64, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer3)
    pool3  = MaxPooling2D(pool_size=(2, 2))(layer3)

    layer4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool3)
    layer4 = Conv2D(128, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer4)
    pool4  = MaxPooling2D(pool_size=(2, 2))(layer4)

    layer5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool4)
    layer5 = Dropout(0.3)(layer5)
    layer5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(layer5)

    upsam1 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(layer5)
    upsam1 = Concatenate()([upsam1, layer4])
    layer6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam1)

    upsam2 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(layer6)
    upsam2 = Concatenate()([upsam2, layer3])
    layer7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam2)

    upsam3 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(layer7)
    upsam3 = Concatenate()([upsam3, layer2])
    layer8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam3)

    upsam4 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(layer8)
    upsam4 = Concatenate()([upsam4, layer1])
    layer9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam4)

    layer10= Conv2D(1, (1, 1), activation='sigmoid')(layer9)

    model = Model(inputs=inputs, outputs=layer10)

    return model

# %%
model = Unet((64, 64, 3))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃ Param # ┃ Connected to         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │       0 │ -                    │
# │ (InputLayer)        │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │     448 │ input_layer[0][0]    │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │   2,320 │ conv2d[0][0]         │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │       0 │ conv2d_1[0][0]       │
# │ (MaxPooling2D)      │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │   4,640 │ max_pooling2d[0][0]  │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │   9,248 │ conv2d_2[0][0]       │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │       0 │ conv2d_3[0][0]       │
# │ (MaxPooling2D)      │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │  18,496 │ max_pooling2d_1[0][… │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │  36,928 │ conv2d_4[0][0]       │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_2     │ (None, 8, 8, 64)  │       0 │ conv2d_5[0][0]       │
# │ (MaxPooling2D)      │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 128) │  73,856 │ max_pooling2d_2[0][… │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 128) │ 147,584 │ conv2d_6[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_3     │ (None, 4, 4, 128) │       0 │ conv2d_7[0][0]       │
# │ (MaxPooling2D)      │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 4, 4, 256) │ 295,168 │ max_pooling2d_3[0][… │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ dropout (Dropout)   │ (None, 4, 4, 256) │       0 │ conv2d_8[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 4, 4, 256) │ 590,080 │ dropout[0][0]        │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 128) │ 131,200 │ conv2d_9[0][0]       │
# │ (Conv2DTranspose)   │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate         │ (None, 8, 8, 256) │       0 │ conv2d_transpose[0]… │
# │ (Concatenate)       │                   │         │ conv2d_7[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 128) │ 295,040 │ concatenate[0][0]    │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │  32,832 │ conv2d_10[0][0]      │
# │ (Conv2DTranspose)   │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │       0 │ conv2d_transpose_1[… │
# │ (Concatenate)       │ 128)              │         │ conv2d_5[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  73,792 │ concatenate_1[0][0]  │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │   8,224 │ conv2d_11[0][0]      │
# │ (Conv2DTranspose)   │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │       0 │ conv2d_transpose_2[… │
# │ (Concatenate)       │ 64)               │         │ conv2d_3[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  18,464 │ concatenate_2[0][0]  │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │   2,064 │ conv2d_12[0][0]      │
# │ (Conv2DTranspose)   │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │       0 │ conv2d_transpose_3[… │
# │ (Concatenate)       │ 32)               │         │ conv2d_1[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │   4,624 │ concatenate_3[0][0]  │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64, 1) │      17 │ conv2d_13[0][0]      │
# └─────────────────────┴───────────────────┴─────────┴──────────────────────┘
#  Total params: 1,745,025 (6.66 MB)
#  Trainable params: 1,745,025 (6.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Define functions for metrics Dice and IoU

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_loss(y_true, y_pred, smooth=100):
    return -dice_coef(y_true, y_pred, smooth)


def iou_coef(y_true, y_pred, smooth=100):
    y_true = K.expand_dims(y_true, axis=-1)
    
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    
    return iou

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', iou_coef, dice_coef])

# %% [markdown]
# ### Fit the model with epochs=25 and batch_size=32

# %%
# history1 = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=25, batch_size=32)

# %%
history2 = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 980ms/step - accuracy: 0.7993 - dice_coef: 0.1634 - iou_coef: 0.0902 - loss: 0.5972 - val_accuracy: 0.8303 - val_dice_coef: 0.1440 - val_iou_coef: 0.0783 - val_loss: 0.5257
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 990ms/step - accuracy: 0.8428 - dice_coef: 0.1412 - iou_coef: 0.0768 - loss: 0.4793 - val_accuracy: 0.8304 - val_dice_coef: 0.2318 - val_iou_coef: 0.1320 - val_loss: 0.4186
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8399 - dice_coef: 0.2444 - iou_coef: 0.1399 - loss: 0.3896 - val_accuracy: 0.8304 - val_dice_coef: 0.2662 - val_iou_coef: 0.1544 - val_loss: 0.3789
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 861ms/step - accuracy: 0.8365 - dice_coef: 0.2650 - iou_coef: 0.1534 - loss: 0.3695 - val_accuracy: 0.8304 - val_dice_coef: 0.2836 - val_iou_coef: 0.1660 - val_loss: 0.3657
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 906ms/step - accuracy: 0.8411 - dice_coef: 0.2720 - iou_coef: 0.1581 - loss: 0.3503 - val_accuracy: 0.8305 - val_dice_coef: 0.2767 - val_iou_coef: 0.1615 - val_loss: 0.3565
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8369 - dice_coef: 0.2977 - iou_coef: 0.1756 - loss: 0.3424 - val_accuracy: 0.8370 - val_dice_coef: 0.3424 - val_iou_coef: 0.2074 - val_loss: 0.3433
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 933ms/step - accuracy: 0.8472 - dice_coef: 0.3349 - iou_coef: 0.2018 - loss: 0.3233 - val_accuracy: 0.8472 - val_dice_coef: 0.3548 - val_iou_coef: 0.2165 - val_loss: 0.3325
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 838ms/step - accuracy: 0.8575 - dice_coef: 0.3470 - iou_coef: 0.2108 - loss: 0.3097 - val_accuracy: 0.8516 - val_dice_coef: 0.3663 - val_iou_coef: 0.2249 - val_loss: 0.3310
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8630 - dice_coef: 0.3592 - iou_coef: 0.2198 - loss: 0.3071 - val_accuracy: 0.8558 - val_dice_coef: 0.3938 - val_iou_coef: 0.2460 - val_loss: 0.3127
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 994ms/step - accuracy: 0.8694 - dice_coef: 0.3736 - iou_coef: 0.2309 - loss: 0.2909 - val_accuracy: 0.8566 - val_dice_coef: 0.4116 - val_iou_coef: 0.2599 - val_loss: 0.3120
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8665 - dice_coef: 0.4120 - iou_coef: 0.2602 - loss: 0.2883 - val_accuracy: 0.8640 - val_dice_coef: 0.4568 - val_iou_coef: 0.2969 - val_loss: 0.2982
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8801 - dice_coef: 0.4392 - iou_coef: 0.2823 - loss: 0.2655 - val_accuracy: 0.8667 - val_dice_coef: 0.4591 - val_iou_coef: 0.2989 - val_loss: 0.2910
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8799 - dice_coef: 0.4708 - iou_coef: 0.3088 - loss: 0.2630 - val_accuracy: 0.8704 - val_dice_coef: 0.4342 - val_iou_coef: 0.2781 - val_loss: 0.2952
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8855 - dice_coef: 0.4528 - iou_coef: 0.2941 - loss: 0.2569 - val_accuracy: 0.8762 - val_dice_coef: 0.4816 - val_iou_coef: 0.3179 - val_loss: 0.2886
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8889 - dice_coef: 0.4821 - iou_coef: 0.3183 - loss: 0.2501 - val_accuracy: 0.8630 - val_dice_coef: 0.5072 - val_iou_coef: 0.3405 - val_loss: 0.3054
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8925 - dice_coef: 0.5110 - iou_coef: 0.3444 - loss: 0.2411 - val_accuracy: 0.8765 - val_dice_coef: 0.4816 - val_iou_coef: 0.3180 - val_loss: 0.2823
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8997 - dice_coef: 0.5185 - iou_coef: 0.3509 - loss: 0.2218 - val_accuracy: 0.8814 - val_dice_coef: 0.5233 - val_iou_coef: 0.3552 - val_loss: 0.2907
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9033 - dice_coef: 0.5650 - iou_coef: 0.3947 - loss: 0.2130 - val_accuracy: 0.8816 - val_dice_coef: 0.5078 - val_iou_coef: 0.3411 - val_loss: 0.2931
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 903ms/step - accuracy: 0.9065 - dice_coef: 0.5716 - iou_coef: 0.4012 - loss: 0.2049 - val_accuracy: 0.8770 - val_dice_coef: 0.5476 - val_iou_coef: 0.3777 - val_loss: 0.2881
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9107 - dice_coef: 0.5910 - iou_coef: 0.4202 - loss: 0.1958 - val_accuracy: 0.8781 - val_dice_coef: 0.4879 - val_iou_coef: 0.3236 - val_loss: 0.3792
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9144 - dice_coef: 0.6240 - iou_coef: 0.4548 - loss: 0.1885 - val_accuracy: 0.8747 - val_dice_coef: 0.5395 - val_iou_coef: 0.3701 - val_loss: 0.2950
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 980ms/step - accuracy: 0.9209 - dice_coef: 0.6384 - iou_coef: 0.4701 - loss: 0.1758 - val_accuracy: 0.8832 - val_dice_coef: 0.5299 - val_iou_coef: 0.3613 - val_loss: 0.3545
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 908ms/step - accuracy: 0.9247 - dice_coef: 0.6634 - iou_coef: 0.4977 - loss: 0.1627 - val_accuracy: 0.8827 - val_dice_coef: 0.5462 - val_iou_coef: 0.3765 - val_loss: 0.3346
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 987ms/step - accuracy: 0.9338 - dice_coef: 0.7102 - iou_coef: 0.5516 - loss: 0.1406 - val_accuracy: 0.8803 - val_dice_coef: 0.5412 - val_iou_coef: 0.3718 - val_loss: 0.3603
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9383 - dice_coef: 0.7360 - iou_coef: 0.5829 - loss: 0.1310 - val_accuracy: 0.8815 - val_dice_coef: 0.5918 - val_iou_coef: 0.4211 - val_loss: 0.3601
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 817ms/step - accuracy: 0.9454 - dice_coef: 0.7658 - iou_coef: 0.6212 - loss: 0.1159 - val_accuracy: 0.8734 - val_dice_coef: 0.5957 - val_iou_coef: 0.4250 - val_loss: 0.3907
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 983ms/step - accuracy: 0.9502 - dice_coef: 0.7856 - iou_coef: 0.6475 - loss: 0.1035 - val_accuracy: 0.8783 - val_dice_coef: 0.5771 - val_iou_coef: 0.4065 - val_loss: 0.4294
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 958ms/step - accuracy: 0.9530 - dice_coef: 0.8043 - iou_coef: 0.6733 - loss: 0.0969 - val_accuracy: 0.8833 - val_dice_coef: 0.5671 - val_iou_coef: 0.3966 - val_loss: 0.4767
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 941ms/step - accuracy: 0.9553 - dice_coef: 0.8129 - iou_coef: 0.6855 - loss: 0.0908 - val_accuracy: 0.8846 - val_dice_coef: 0.5898 - val_iou_coef: 0.4190 - val_loss: 0.4769
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9563 - dice_coef: 0.8238 - iou_coef: 0.7009 - loss: 0.0878 - val_accuracy: 0.8819 - val_dice_coef: 0.6000 - val_iou_coef: 0.4294 - val_loss: 0.4121
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 937ms/step - accuracy: 0.9576 - dice_coef: 0.8349 - iou_coef: 0.7170 - loss: 0.0852 - val_accuracy: 0.8823 - val_dice_coef: 0.5954 - val_iou_coef: 0.4248 - val_loss: 0.4350
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 915ms/step - accuracy: 0.9605 - dice_coef: 0.8410 - iou_coef: 0.7261 - loss: 0.0791 - val_accuracy: 0.8877 - val_dice_coef: 0.5921 - val_iou_coef: 0.4215 - val_loss: 0.4841
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9630 - dice_coef: 0.8472 - iou_coef: 0.7353 - loss: 0.0714 - val_accuracy: 0.8737 - val_dice_coef: 0.5964 - val_iou_coef: 0.4257 - val_loss: 0.4651
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9643 - dice_coef: 0.8570 - iou_coef: 0.7502 - loss: 0.0684 - val_accuracy: 0.8777 - val_dice_coef: 0.6064 - val_iou_coef: 0.4358 - val_loss: 0.4608
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 893ms/step - accuracy: 0.9649 - dice_coef: 0.8661 - iou_coef: 0.7642 - loss: 0.0669 - val_accuracy: 0.8910 - val_dice_coef: 0.6227 - val_iou_coef: 0.4532 - val_loss: 0.4744
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 920ms/step - accuracy: 0.9685 - dice_coef: 0.8792 - iou_coef: 0.7848 - loss: 0.0582 - val_accuracy: 0.8932 - val_dice_coef: 0.6348 - val_iou_coef: 0.4658 - val_loss: 0.5348
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 883ms/step - accuracy: 0.9698 - dice_coef: 0.8864 - iou_coef: 0.7963 - loss: 0.0551 - val_accuracy: 0.8865 - val_dice_coef: 0.6278 - val_iou_coef: 0.4583 - val_loss: 0.5406
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 919ms/step - accuracy: 0.9717 - dice_coef: 0.8960 - iou_coef: 0.8118 - loss: 0.0504 - val_accuracy: 0.8908 - val_dice_coef: 0.6225 - val_iou_coef: 0.4527 - val_loss: 0.5155
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 870ms/step - accuracy: 0.9712 - dice_coef: 0.8932 - iou_coef: 0.8073 - loss: 0.0509 - val_accuracy: 0.8901 - val_dice_coef: 0.6426 - val_iou_coef: 0.4740 - val_loss: 0.5267
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 847ms/step - accuracy: 0.9721 - dice_coef: 0.9033 - iou_coef: 0.8239 - loss: 0.0485 - val_accuracy: 0.8898 - val_dice_coef: 0.6298 - val_iou_coef: 0.4604 - val_loss: 0.5370
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 618ms/step - accuracy: 0.9728 - dice_coef: 0.9068 - iou_coef: 0.8297 - loss: 0.0467 - val_accuracy: 0.8840 - val_dice_coef: 0.6360 - val_iou_coef: 0.4671 - val_loss: 0.5397
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 676ms/step - accuracy: 0.9731 - dice_coef: 0.9097 - iou_coef: 0.8346 - loss: 0.0463 - val_accuracy: 0.8900 - val_dice_coef: 0.6216 - val_iou_coef: 0.4518 - val_loss: 0.5989
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 892ms/step - accuracy: 0.9739 - dice_coef: 0.9098 - iou_coef: 0.8348 - loss: 0.0439 - val_accuracy: 0.8842 - val_dice_coef: 0.6300 - val_iou_coef: 0.4607 - val_loss: 0.5683
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 918ms/step - accuracy: 0.9749 - dice_coef: 0.9165 - iou_coef: 0.8461 - loss: 0.0411 - val_accuracy: 0.8903 - val_dice_coef: 0.6376 - val_iou_coef: 0.4688 - val_loss: 0.6193
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 984ms/step - accuracy: 0.9764 - dice_coef: 0.9247 - iou_coef: 0.8601 - loss: 0.0370 - val_accuracy: 0.8916 - val_dice_coef: 0.6310 - val_iou_coef: 0.4618 - val_loss: 0.6373
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9765 - dice_coef: 0.9270 - iou_coef: 0.8641 - loss: 0.0367 - val_accuracy: 0.8871 - val_dice_coef: 0.6398 - val_iou_coef: 0.4711 - val_loss: 0.6012
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 893ms/step - accuracy: 0.9764 - dice_coef: 0.9267 - iou_coef: 0.8636 - loss: 0.0367 - val_accuracy: 0.8909 - val_dice_coef: 0.6366 - val_iou_coef: 0.4678 - val_loss: 0.6266
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 939ms/step - accuracy: 0.9776 - dice_coef: 0.9300 - iou_coef: 0.8693 - loss: 0.0343 - val_accuracy: 0.8890 - val_dice_coef: 0.6389 - val_iou_coef: 0.4702 - val_loss: 0.6199
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 763ms/step - accuracy: 0.9784 - dice_coef: 0.9337 - iou_coef: 0.8759 - loss: 0.0321 - val_accuracy: 0.8884 - val_dice_coef: 0.6377 - val_iou_coef: 0.4689 - val_loss: 0.6315
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 781ms/step - accuracy: 0.9786 - dice_coef: 0.9338 - iou_coef: 0.8760 - loss: 0.0320 - val_accuracy: 0.8919 - val_dice_coef: 0.6365 - val_iou_coef: 0.4676 - val_loss: 0.6441

# %% [markdown]
# Thus, increasing batch_size, increases Dice and Iou=U. So, evaluate the model with second one.

# %% [markdown]
# ## Results and analysis

# %%
loss, accuracy, iou, dice = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}\nTest Accuracy: {accuracy}\nIoU: {iou}\nDice: {dice}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.8935 - dice_coef: 0.6490 - iou_coef: 0.4838 - loss: 0.5850
# Test Loss: 0.4968670606613159
# Test Accuracy: 0.8963574171066284
# IoU: 0.673858642578125
# Dice: 0.5128602385520935

# %% [markdown]
# ### Plot training metrics

# %%
def plot_training(hist):

    # Define needed variables
    tr_acc = hist.history['accuracy']
    tr_iou = hist.history['iou_coef']
    tr_dice = hist.history['dice_coef']
    tr_loss = hist.history['loss']

    val_acc = hist.history['val_accuracy']
    val_iou = hist.history['val_iou_coef']
    val_dice = hist.history['val_dice_coef']
    val_loss = hist.history['val_loss']

    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    index_iou = np.argmax(iou_coef)
    iou_highest = val_iou[index_iou]
    index_dice = np.argmax(dice_coef)
    dice_highest = val_dice[index_dice]
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]

    Epochs = [i+1 for i in range(len(tr_acc))]

    acc_label = f'best epoch= {str(index_acc + 1)}'
    iou_label = f'best epoch= {str(index_iou + 1)}'
    dice_label = f'best epoch= {str(index_dice + 1)}'
    loss_label = f'best epoch= {str(index_loss + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 20))
    plt.style.use('fivethirtyeight')

    # Training Accuracy
    plt.subplot(2, 2, 1)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training IoU
    plt.subplot(2, 2, 2)
    plt.plot(Epochs, tr_iou, 'r', label= 'Training IoU')
    plt.plot(Epochs, val_iou, 'g', label= 'Validation IoU')
    plt.scatter(index_iou + 1 , iou_highest, s= 150, c= 'blue', label= iou_label)
    plt.title('Training and Validation IoU Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('IoU')
    plt.legend()

    # Training Dice
    plt.subplot(2, 2, 3)
    plt.plot(Epochs, tr_dice, 'r', label= 'Training Dice')
    plt.plot(Epochs, val_dice, 'g', label= 'Validation Dice')
    plt.scatter(index_dice + 1 , dice_highest, s= 150, c= 'blue', label= dice_label)
    plt.title('Training and Validation Dice Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('Dice')
    plt.legend()

    # Training Loss
    plt.subplot(2, 2, 4)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
# plot_training(history1)

# %%
plot_training(history2)

# %% [markdown]
# ### Show the predictions

# %%
predictions = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step

# %%
num_images = 10
plt.figure(figsize=(20, 8))
for i in range(10):
    plt.subplot(3, num_images, i + 1)
    plt.imshow(X_test[i])
    plt.title('Test Image')
    plt.axis('off')
    
    plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(y_test[i], cmap='gray')
    plt.title('Test Mask')
    plt.axis('off')
    
    plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(predictions[i], cmap='gray')
    plt.title('Predicted Mask')
    plt.axis('off')

plt.show()

# %%
def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(tf.round(y_pred), 1)), tf.float32))
    predicted_positives = tf.reduce_sum(tf.cast(tf.equal(tf.round(y_pred), 1), tf.float32))
    precision = true_positives / (predicted_positives + 1e-6)  # Add a small constant to avoid division by zero
    return precision

def recall(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true, 1), tf.equal(tf.round(y_pred), 1)), tf.float32))
    actual_positives = tf.reduce_sum(tf.cast(tf.equal(y_true, 1), tf.float32))
    recall = true_positives / (actual_positives + 1e-6)  # Add a small constant to avoid division by zero
    return recall

def dice_coefficient(y_test, y_pred):
    target_shape = (y_test.shape[0], y_test.shape[1])
    y_test = y_test.reshape(target_shape)
    y_pred = y_pred.reshape(target_shape)

    prec = precision(y_test, y_pred)
    rec = recall(y_test, y_pred)
    f1 = 2 * (prec * rec) / (prec + rec + 1e-6)  # Add a small constant to avoid division by zero
    return f1

# %%
f1 = 0
for i in range(100):
    f1 += dice_coefficient(y_test[i], predictions[i])

print(f1/100)
# Out:
# tf.Tensor(0.60769874, shape=(), dtype=float32)
