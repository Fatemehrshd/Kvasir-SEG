# %% [markdown]
# # U-net Model with fig-size 64*64 and the traning plots

# %% [markdown]
# Import libraries here:

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import os
import cv2

from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Preprocessing
# In this section, I will resize images and normalize them using cv2 library and

# %% [markdown]
# ### Resizing

# %% [markdown]
# read images and resize them: size = (64, 64, 3)

# %%
def read_images_from_folder_and_resizing(img_folder_path, mask_folder_path):
    images = []
    masks  = []
    img_paths  = []
    mask_paths = []
    for image_name in sorted(os.listdir(img_folder_path)):
        image_path = os.path.join(img_folder_path, image_name)
        img_paths.append(image_path)

    for mask_name in sorted(os.listdir(mask_folder_path)):
        mask_path = os.path.join(mask_folder_path, mask_name)
        mask_paths.append(mask_path)

    for img_path, mask_path in zip(img_paths, mask_paths):
        img  = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        desired_size = (64, 64)
        img  = cv2.resize(img, desired_size)
        mask = cv2.resize(mask, desired_size)

        images.append(img)
        masks.append(mask)
    return images, masks, img_paths, mask_paths



images_folder_path = 'Kvasir-SEG/images'
masks_folder_path  = 'Kvasir-SEG/masks'

images, masks, img_p, mask_p = read_images_from_folder_and_resizing(images_folder_path, masks_folder_path)
images = np.array(images)
masks  = np.array(masks)

# %% [markdown]
# ### Normalizing

# %%
images = images / 255.
masks  = masks / 255.

print("Max pixel value (mask):", np.max(images))
print("Min pixel value (mask):", np.min(masks))
# Out:
# Max pixel value (mask): 1.0
# Min pixel value (mask): 0.0

# %% [markdown]
# ### Display an instance of normalized images and its mask

# %%
plt.figure(figsize=(10, 5))

# Display the first image in dataset
plt.subplot(1, 2, 1)
plt.imshow(images[2])
plt.title('Image')

# Display the first mask
plt.subplot(1, 2, 2)
plt.imshow(masks[2], cmap='gray')
plt.title('Mask')

plt.show()

# %% [markdown]
# ### Spliting data into train, validation, and test
# In this section, i splited data into train, test, and validation with ration 0.8, 0.1, 0.1

# %%
def split_data(images, masks, split=0.1):
    total_size = len(images)
    test_size  = int(split * total_size)
    valid_size = int(split * total_size)

    X_train, X_valid = train_test_split(images, test_size=valid_size, random_state=42)
    y_train, y_valid = train_test_split(masks, test_size=valid_size, random_state=42)

    X_train, X_test = train_test_split(X_train, test_size=test_size, random_state=42)
    y_train, y_test = train_test_split(y_train, test_size=test_size, random_state=42)
    return (X_train, y_train), (X_valid, y_valid), (X_test, y_test)

# %%
(X_train, y_train), (X_valid, y_valid), (X_test, y_test) = split_data(images, masks)

print(f"train set size: {len(X_train)}\nvalid set size: {len(X_valid)}\ntest set size:  {len(X_test)}")
# Out:
# train set size: 800
# valid set size: 100
# test set size:  100

# %% [markdown]
# ## Construct U-net model

# %% [markdown]
# In this section, I constructed a U-net model which has 10 layers, 4 down-sampling, 1 buttleneck, 4 upsampling, and an output.

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Concatenate, UpSampling2D, Conv2DTranspose, BatchNormalization, Dropout
from tensorflow.keras.models import Model

def Unet(input_shape):
    
    # Encoder
    inputs = Input(input_shape)

    layer1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    layer1 = Conv2D(16, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer1)
    pool1  = MaxPooling2D(pool_size=(2, 2))(layer1)

    layer2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool1)
    layer2 = Conv2D(32, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer2)
    pool2  = MaxPooling2D(pool_size=(2, 2))(layer2)

    layer3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool2)
    layer3 = Conv2D(64, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer3)
    pool3  = MaxPooling2D(pool_size=(2, 2))(layer3)

    layer4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool3)
    layer4 = Conv2D(128, [3, 3], activation='relu', kernel_initializer='he_normal', padding='same')(layer4)
    pool4  = MaxPooling2D(pool_size=(2, 2))(layer4)

    # Buttleneck
    layer5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool4)
    layer5 = Dropout(0.3)(layer5)
    layer5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(layer5)

    # Decoder
    upsam1 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(layer5)
    upsam1 = Concatenate()([upsam1, layer4])
    layer6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam1)

    upsam2 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(layer6)
    upsam2 = Concatenate()([upsam2, layer3])
    layer7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam2)

    upsam3 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(layer7)
    upsam3 = Concatenate()([upsam3, layer2])
    layer8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam3)

    upsam4 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(layer8)
    upsam4 = Concatenate()([upsam4, layer1])
    layer9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(upsam4)

    # Output
    layer10= Conv2D(1, (1, 1), activation='sigmoid')(layer9)

    model = Model(inputs=inputs, outputs=layer10)

    return model

# %% [markdown]
# Now, it's time to take a summary of what we made!

# %%
model = Unet((64, 64, 3))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃ Param # ┃ Connected to         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │       0 │ -                    │
# │ (InputLayer)        │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │     448 │ input_layer[0][0]    │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │   2,320 │ conv2d[0][0]         │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │       0 │ conv2d_1[0][0]       │
# │ (MaxPooling2D)      │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │   4,640 │ max_pooling2d[0][0]  │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │   9,248 │ conv2d_2[0][0]       │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │       0 │ conv2d_3[0][0]       │
# │ (MaxPooling2D)      │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │  18,496 │ max_pooling2d_1[0][… │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │  36,928 │ conv2d_4[0][0]       │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_2     │ (None, 8, 8, 64)  │       0 │ conv2d_5[0][0]       │
# │ (MaxPooling2D)      │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 128) │  73,856 │ max_pooling2d_2[0][… │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 128) │ 147,584 │ conv2d_6[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ max_pooling2d_3     │ (None, 4, 4, 128) │       0 │ conv2d_7[0][0]       │
# │ (MaxPooling2D)      │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 4, 4, 256) │ 295,168 │ max_pooling2d_3[0][… │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ dropout (Dropout)   │ (None, 4, 4, 256) │       0 │ conv2d_8[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 4, 4, 256) │ 590,080 │ dropout[0][0]        │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 128) │ 131,200 │ conv2d_9[0][0]       │
# │ (Conv2DTranspose)   │                   │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate         │ (None, 8, 8, 256) │       0 │ conv2d_transpose[0]… │
# │ (Concatenate)       │                   │         │ conv2d_7[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 128) │ 295,040 │ concatenate[0][0]    │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │  32,832 │ conv2d_10[0][0]      │
# │ (Conv2DTranspose)   │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │       0 │ conv2d_transpose_1[… │
# │ (Concatenate)       │ 128)              │         │ conv2d_5[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  73,792 │ concatenate_1[0][0]  │
# │                     │ 64)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │   8,224 │ conv2d_11[0][0]      │
# │ (Conv2DTranspose)   │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │       0 │ conv2d_transpose_2[… │
# │ (Concatenate)       │ 64)               │         │ conv2d_3[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  18,464 │ concatenate_2[0][0]  │
# │                     │ 32)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │   2,064 │ conv2d_12[0][0]      │
# │ (Conv2DTranspose)   │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │       0 │ conv2d_transpose_3[… │
# │ (Concatenate)       │ 32)               │         │ conv2d_1[0][0]       │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │   4,624 │ concatenate_3[0][0]  │
# │                     │ 16)               │         │                      │
# ├─────────────────────┼───────────────────┼─────────┼──────────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64, 1) │      17 │ conv2d_13[0][0]      │
# └─────────────────────┴───────────────────┴─────────┴──────────────────────┘
#  Total params: 1,745,025 (6.66 MB)
#  Trainable params: 1,745,025 (6.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# As it is obvious, in the model we construcete, there are 1,745,025 parameters which our model will lean them all during training time.

# %% [markdown]
# ### Define functions for metrics Dice and IoU
# As the shape of my model output is not same as what libraries get to compute Dice and IoU, we define this functions by myself.

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_loss(y_true, y_pred, smooth=100):
    return -dice_coef(y_true, y_pred, smooth)


def iou_coef(y_true, y_pred, smooth=100):
    y_true = K.expand_dims(y_true, axis=-1)
    
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    
    return iou

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', iou_coef, dice_coef])

# %% [markdown]
# ### Fit the model with epochs=25 and batch_size=32

# %%
history1 = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=25, batch_size=32)
# Out:
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 403ms/step - accuracy: 0.6200 - dice_coef: 0.2048 - iou_coef: 0.1161 - loss: 0.6035 - val_accuracy: 0.8304 - val_dice_coef: 0.2593 - val_iou_coef: 0.1525 - val_loss: 0.3806
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 456ms/step - accuracy: 0.8384 - dice_coef: 0.2705 - iou_coef: 0.1577 - loss: 0.3686 - val_accuracy: 0.8304 - val_dice_coef: 0.2861 - val_iou_coef: 0.1712 - val_loss: 0.3564
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 491ms/step - accuracy: 0.8424 - dice_coef: 0.2902 - iou_coef: 0.1711 - loss: 0.3448 - val_accuracy: 0.8304 - val_dice_coef: 0.2937 - val_iou_coef: 0.1757 - val_loss: 0.3684
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s
50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 769ms/step - accuracy: 0.9842 - dice_coef: 0.9677 - iou_coef: 0.9374 - loss: 0.0155 - val_accuracy: 0.8945 - val_dice_coef: 0.6655 - val_iou_coef: 0.4997 - val_loss: 0.7784
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 785ms/step - accuracy: 0.9847 - dice_coef: 0.9696 - iou_coef: 0.9412 - loss: 0.0145 - val_accuracy: 0.8949 - val_dice_coef: 0.6636 - val_iou_coef: 0.4974 - val_loss: 0.7875
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 733ms/step - accuracy: 0.9837 - dice_coef: 0.9694 - iou_coef: 0.9407 - loss: 0.0158 - val_accuracy: 0.8944 - val_dice_coef: 0.6697 - val_iou_coef: 0.5043 - val_loss: 0.7844
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 658ms/step - accuracy: 0.9844 - dice_coef: 0.9702 - iou_coef: 0.9422 - loss: 0.0147 - val_accuracy: 0.8947 - val_dice_coef: 0.6654 - val_iou_coef: 0.4995 - val_loss: 0.7816
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 681ms/step - accuracy: 0.9842 - dice_coef: 0.9704 - iou_coef: 0.9426 - loss: 0.0148 - val_accuracy: 0.8947 - val_dice_coef: 0.6677 - val_iou_coef: 0.5021 - val_loss: 0.7980
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 720ms/step - accuracy: 0.9847 - dice_coef: 0.9713 - iou_coef: 0.9444 - loss: 0.0140 - val_accuracy: 0.8945 - val_dice_coef: 0.6609 - val_iou_coef: 0.4943 - val_loss: 0.8054
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 0.9846 - dice_coef: 0.9714 - iou_coef: 0.9444 - loss: 0.0140 - val_accuracy: 0.8956 - val_dice_coef: 0.6705 - val_iou_coef: 0.5052 - val_loss: 0.8147

# %%
history3 = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=50, batch_size=16)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.8720 - dice_coef: 0.3991 - iou_coef: 0.2541 - loss: 0.2969 - val_accuracy: 0.8825 - val_dice_coef: 0.4936 - val_iou_coef: 0.3355 - val_loss: 0.2953
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.9086 - dice_coef: 0.5607 - iou_coef: 0.3945 - loss: 0.2094 - val_accuracy: 0.9004 - val_dice_coef: 0.5636 - val_iou_coef: 0.3994 - val_loss: 0.2674
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 236ms/step - accuracy: 0.9243 - dice_coef: 0.6696 - iou_coef: 0.5077 - loss: 0.1651 - val_accuracy: 0.8955 - val_dice_coef: 0.6103 - val_iou_coef: 0.4451 - val_loss: 0.2835
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 343ms/step - accuracy: 0.9458 - dice_coef: 0.7534 - iou_coef: 0.6093 - loss: 0.1198 - val_accuracy: 0.9037 - val_dice_coef: 0.6205 - val_iou_coef: 0.4546 - val_loss: 0.2628
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 244ms/step - accuracy: 0.9511 - dice_coef: 0.7983 - iou_coef: 0.6664 - loss: 0.1029 - val_accuracy: 0.9048 - val_dice_coef: 0.6539 - val_iou_coef: 0.4910 - val_loss: 0.3057
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s
50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 213ms/step - accuracy: 0.9859 - dice_coef: 0.9782 - iou_coef: 0.9575 - loss: 0.0105 - val_accuracy: 0.8995 - val_dice_coef: 0.6903 - val_iou_coef: 0.5330 - val_loss: 0.6822
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 251ms/step - accuracy: 0.9853 - dice_coef: 0.9771 - iou_coef: 0.9555 - loss: 0.0115 - val_accuracy: 0.9024 - val_dice_coef: 0.6917 - val_iou_coef: 0.5349 - val_loss: 0.6650
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 250ms/step - accuracy: 0.9852 - dice_coef: 0.9773 - iou_coef: 0.9558 - loss: 0.0117 - val_accuracy: 0.9030 - val_dice_coef: 0.6975 - val_iou_coef: 0.5410 - val_loss: 0.6569
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 277ms/step - accuracy: 0.9859 - dice_coef: 0.9780 - iou_coef: 0.9572 - loss: 0.0104 - val_accuracy: 0.9020 - val_dice_coef: 0.6907 - val_iou_coef: 0.5335 - val_loss: 0.6957
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 216ms/step - accuracy: 0.9858 - dice_coef: 0.9789 - iou_coef: 0.9589 - loss: 0.0104 - val_accuracy: 0.9018 - val_dice_coef: 0.6910 - val_iou_coef: 0.5339 - val_loss: 0.7113
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 242ms/step - accuracy: 0.9849 - dice_coef: 0.9744 - iou_coef: 0.9503 - loss: 0.0154 - val_accuracy: 0.9040 - val_dice_coef: 0.7074 - val_iou_coef: 0.5538 - val_loss: 0.5140

# %% [markdown]
# Thus, increasing batch_size, increases Dice and Iou=U. So, evaluate the model with second one.

# %% [markdown]
# ## Results and analysis

# %% [markdown]
# Evaluate model on test data

# %%
loss, accuracy, iou, dice = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}\nTest Accuracy: {accuracy}\nIoU: {iou}\nDice: {dice}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8992 - dice_coef: 0.6970 - iou_coef: 0.5369 - loss: 0.5692
# Test Loss: 0.5583736300468445
# Test Accuracy: 0.8983715772628784
# IoU: 0.6862320899963379
# Dice: 0.5257070660591125

# %% [markdown]
# ### IoU: 0.686, Dice: 0.53

# %% [markdown]
# ### Plot training metrics

# %%
def plot_training(hist):

    # Define needed variables
    tr_acc = hist.history['accuracy']
    tr_iou = hist.history['iou_coef']
    tr_dice = hist.history['dice_coef']
    tr_loss = hist.history['loss']

    val_acc = hist.history['val_accuracy']
    val_iou = hist.history['val_iou_coef']
    val_dice = hist.history['val_dice_coef']
    val_loss = hist.history['val_loss']

    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    index_iou = np.argmax(iou_coef)
    iou_highest = val_iou[index_iou]
    index_dice = np.argmax(dice_coef)
    dice_highest = val_dice[index_dice]
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]

    Epochs = [i+1 for i in range(len(tr_acc))]

    acc_label = f'best epoch= {str(index_acc + 1)}'
    iou_label = f'best epoch= {str(index_iou + 1)}'
    dice_label = f'best epoch= {str(index_dice + 1)}'
    loss_label = f'best epoch= {str(index_loss + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 20))
    plt.style.use('fivethirtyeight')

    # Training Accuracy
    plt.subplot(2, 2, 1)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training IoU
    plt.subplot(2, 2, 2)
    plt.plot(Epochs, tr_iou, 'r', label= 'Training IoU')
    plt.plot(Epochs, val_iou, 'g', label= 'Validation IoU')
    plt.scatter(index_iou + 1 , iou_highest, s= 150, c= 'blue', label= iou_label)
    plt.title('Training and Validation IoU Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('IoU')
    plt.legend()

    # Training Dice
    plt.subplot(2, 2, 3)
    plt.plot(Epochs, tr_dice, 'r', label= 'Training Dice')
    plt.plot(Epochs, val_dice, 'g', label= 'Validation Dice')
    plt.scatter(index_dice + 1 , dice_highest, s= 150, c= 'blue', label= dice_label)
    plt.title('Training and Validation Dice Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('Dice')
    plt.legend()

    # Training Loss
    plt.subplot(2, 2, 4)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
plot_training(history3)

# %% [markdown]
# ### Show the predictions

# %%
predictions = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step

# %%
num_images = 10
plt.figure(figsize=(20, 8))
for i in range(10):
    plt.subplot(3, num_images, i + 1)
    plt.imshow(X_test[i])
    plt.title('Test Image')
    plt.axis('off')
    
    plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(y_test[i], cmap='gray')
    plt.title('Test Mask')
    plt.axis('off')
    
    plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(predictions[i], cmap='gray')
    plt.title('Pred Mask')
    plt.axis('off')

plt.show()

# %%
def compute_precision(pred, mask):
    TP    = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(mask, 1), tf.equal(tf.round(pred), 1)), tf.float32))
    TP_FP = tf.reduce_sum(tf.cast(tf.equal(tf.round(pred), 1), tf.float32))
    return (TP / (TP_FP + 1e-6))


def compute_recall(pred, mask):
    TP = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(mask, 1), tf.equal(tf.round(pred), 1)), tf.float32))
    P  = tf.reduce_sum(tf.cast(tf.equal(mask, 1), tf.float32))
    return (TP / (P + 1e-6))

def Dice_coefficient(pred, mask):
    dim1, dim2 = mask.shape[0], mask.shape[1]
    target_shape = (dim1, dim2)
    mask = mask.reshape(target_shape)
    pred = pred.reshape(target_shape)
    precision = compute_precision(pred, mask)
    recall    = compute_recall(pred, mask)
    return precision, recall


def compute_F1(pred, mask):
    precision, recall = Dice_coefficient(pred, mask)
    return 2 * (precision * recall) / (precision + recall + 1e-6)

# %%
f1 = 0
for i in range(100):
    f1 += compute_F1(y_test[i], predictions[i])

print(f1/100)
# Out:
# tf.Tensor(0.6800355, shape=(), dtype=float32)

# %% [markdown]
# #### So, the F1-Score or Dice coefficient of this model is 0.68 which is near 70%.
